# %% [markdown]
# import sys
# from pathlib import Path
#
# # allow importing the src package from notebooks/
# ROOT = Path("..").resolve()
# sys.path.insert(0, str(ROOT / "src"))
#
# from image_ambiguity import CocoDatasetLoader
# from image_ambiguity.config import get_settings
# from image_ambiguity.logging_config import setup_logging
#
# setup_logging()
# settings = get_settings()
#
# loader = CocoDatasetLoader(settings.annotation_file, settings.image_dir)
# loader.load_annotations()
#
# sample = loader.get_random_sample(seed=settings.random_seed)
# print("Dataset size:", len(loader))
# print("Sample image_id:", sample["image_id"])
# print("Captions:")
# for caption in sample["captions"]:
#     print("-", caption)

# %%
# Display the sampled image with captions
loader.show_image_with_captions(sample["image_id"])
